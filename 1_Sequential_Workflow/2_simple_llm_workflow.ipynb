# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model='llama-3.1-8b-instant')

# %%
#create a state 
class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    #Extract the ques from state 
    question = state["question"]

    #form a prompt
    prompt = f"Answer the following question {question}"

    #ask that ques to LLM 
    answer = model.invoke(prompt).content

    #update the ans in state
    state["answer"] = answer

    return state

# %%
#create our graph

graph = StateGraph(LLMState)

#add node
graph.add_node("llm_qa", llm_qa)

#add edges
graph.add_edge(START, "llm_qa")
graph.add_edge("llm_qa", END)

#compile
workflow = graph.compile()

# %%
#execute 

initial_state = {"question": "how far is moon from the earth?"}

final_state = workflow.invoke(initial_state)

print(final_state["answer"])
# Out:
# The average distance from the Earth to the Moon is approximately 384,400 kilometers (238,900 miles). This distance is constantly changing due to the elliptical shape of the Moon's orbit around the Earth. At its closest point (perigee), the Moon is about 363,300 kilometers (225,600 miles) away, and at its farthest point (apogee), it is about 405,500 kilometers (252,100 miles) away.
